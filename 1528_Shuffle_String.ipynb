# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamsi-Akhumukhi/LeetCode/blob/master/1528_Shuffle_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given a string s and an integer array indices of the same length.
#
# The string s will be shuffled such that the character at the ith position moves to indices[i] in the shuffled string.
#
# Return the shuffled string.

# %% [markdown]
# ![Screenshot 2020-09-15 214202.png](data:image/png;base64,...)

# %%
indices = [4,5,6,7,0,2,1,3]

# %%
s = "codeleet"

# %%
st = []

# %%
 for i in range(len(indices)):
            index = indices.index(i) 
            print(index)
            st += s[index]
            print(st)
# Out:
# 4
# ['l']
# 6
# ['l', 'e']
# 5
# ['l', 'e', 'e']
# 7
# ['l', 'e', 'e', 't']
# 0
# ['l', 'e', 'e', 't', 'c']
# 1
# ['l', 'e', 'e', 't', 'c', 'o']
# 2
# ['l', 'e', 'e', 't', 'c', 'o', 'd']
# 3
# ['l', 'e', 'e', 't', 'c', 'o', 'd', 'e']
